# %% [markdown]
# # Pose Pipeline
#
# This notebook walks through video loading, pose extraction, visualization and data export.

# %%
import sys
from pathlib import Path
from IPython.display import Video
import pandas as pd
import numpy as np
import cv2

#Import the pose_pipeline model
from models.pose_pipeline import PosePipeline

# Add project root to Python path so we can import ml module
project_root = Path(__file__).parent.parent if '__file__' in globals() else Path().resolve().parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

# %%
#Define video path
video_path = "../data/raw/videos/sample_good_shot.mp4"

# %%
#Instantiate PosePipeline
pose_pipeline = PosePipeline()
# Out:
# Model loaded successfully.

# %%
#Processes the video and returns a pandas dataframe containing keypoints (specific body parts  / joints), confidence level and x,y coordinates.
results = pose_pipeline.process_video(video_path)

# %% [markdown]
# **Data Export**
#
# The following dataframe has the following columns:
# - frame: Represents the frame 0 to n.
# - keypoint: Integer representation of a body part, ex. 1 is Left eye.
# - x: x coordinate in the frame of the keypoint.
# - y: y coordinate in the frame of the keypoint.
# - confidence: confidence level.

# %%
print(results)
# Out:
#       frame  keypoint           x           y  confidence
# 0         0         0  932.666138  507.891052    0.944163
# 1         0         1  944.647217  500.020966    0.944025
# 2         0         2  926.966248  499.110352    0.698841
# 3         0         3  971.585083  510.051300    0.921639
# 4         0         4  928.234619  508.446075    0.301193
# ...     ...       ...         ...         ...         ...
# 1134     66        12  909.207886  676.360657    0.994243
# 1135     66        13  960.401855  809.508606    0.991680
# 1136     66        14  895.763428  811.693481    0.982389
# 1137     66        15  993.740784  926.484985    0.942214
# 1138     66        16  913.520874  937.948608    0.911847
#
# [1139 rows x 5 columns]

# %% [markdown]
# **Visualization Using Data**
#
# Use the exported data to create a pose overlay visualization of the shooter.

# %%
# COCO skeleton connections
SKELETON = [
    # arms
    (5, 7), (7, 9),      # left arm
    (6, 8), (8, 10),     # right arm

    # shoulders
    (5, 6),

    # torso (THIS IS WHAT YOU WERE MISSING)
    (5, 11),             # left shoulder → left hip
    (6, 12),             # right shoulder → right hip
    (11, 12),            # hips
    (5, 6),              # shoulders (top of torso)

    # legs
    (11, 13), (13, 15),  # left leg
    (12, 14), (14, 16),  # right leg
]


def render_shooter_video(video_path, pose_df, output_path):
    cap = cv2.VideoCapture(video_path)

    width  = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps    = cap.get(cv2.CAP_PROP_FPS) or 30

    out = cv2.VideoWriter(
        output_path,
        cv2.VideoWriter_fourcc(*"mp4v"),
        fps,
        (width, height)
    )

    frame_idx = 0

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        frame_data = pose_df[pose_df["frame"] == frame_idx]

        # Draw joints
        for _, row in frame_data.iterrows():
            x, y = int(row.x), int(row.y)
            cv2.circle(frame, (x, y), 4, (0, 0, 255), -1)

        # Draw bones
        for a, b in SKELETON:
            pa = frame_data[frame_data["keypoint"] == a]
            pb = frame_data[frame_data["keypoint"] == b]
            if not pa.empty and not pb.empty:
                x1, y1 = int(pa.x.values[0]), int(pa.y.values[0])
                x2, y2 = int(pb.x.values[0]), int(pb.y.values[0])
                cv2.line(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)

        out.write(frame)
        frame_idx += 1

    cap.release()
    out.release()

# %% [markdown]
# **Rendering**
#
# The video does not display on the IDE, but works on an MP4 player.

# %%
#Render the video with pose overlay

df = pose_pipeline.process_video(video_path)

render_shooter_video(
    video_path,
    df,
    "../data/processed/shooter_only3.mp4"
)
# Out:
# video 1/1 (frame 1/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 2 persons, 47.3ms
# video 1/1 (frame 2/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 3 persons, 45.1ms
# video 1/1 (frame 3/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 4 persons, 42.6ms
# video 1/1 (frame 4/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 3 persons, 50.0ms
# video 1/1 (frame 5/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 2 persons, 40.1ms
# video 1/1 (frame 6/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 3 persons, 35.4ms
# video 1/1 (frame 7/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 2 persons, 31.5ms
# video 1/1 (frame 8/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 2 persons, 32.6ms
# video 1/1 (frame 9/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 2 persons, 31.2ms
# video 1/1 (frame 10/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 2 persons, 38.3ms
# video 1/1 (frame 11/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 3 persons, 38.8ms
# video 1/1 (frame 12/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 3 persons, 33.7ms
# video 1/1 (frame 13/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 2 persons, 31.5ms
# video 1/1 (frame 14/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 2 persons, 32.4ms
# video 1/1 (frame 15/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 3 persons, 36.0ms
# video 1/1 (frame 16/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 3 persons, 37.8ms
# video 1/1 (frame 17/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 4 persons, 47.6ms
# video 1/1 (frame 18/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 3 persons, 34.9ms
# video 1/1 (frame 19/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 4 persons, 32.9ms
# video 1/1 (frame 20/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 3 persons, 32.7ms
# video 1/1 (frame 21/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 3 persons, 33.2ms
# video 1/1 (frame 22/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 3 persons, 32.7ms
# video 1/1 (frame 23/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 3 persons, 93.6ms
# video 1/1 (frame 24/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 4 persons, 37.2ms
# video 1/1 (frame 25/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 4 persons, 37.7ms
# video 1/1 (frame 26/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 3 persons, 38.6ms
# video 1/1 (frame 27/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 4 persons, 46.4ms
# video 1/1 (frame 28/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 3 persons, 46.0ms
# video 1/1 (frame 29/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 3 persons, 38.9ms
# video 1/1 (frame 30/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 2 persons, 37.6ms
# video 1/1 (frame 31/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 3 persons, 37.9ms
# video 1/1 (frame 32/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 3 persons, 41.8ms
# video 1/1 (frame 33/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 3 persons, 47.7ms
# video 1/1 (frame 34/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 3 persons, 36.1ms
# video 1/1 (frame 35/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 3 persons, 35.0ms
# video 1/1 (frame 36/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 3 persons, 41.6ms
# video 1/1 (frame 37/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 3 persons, 40.8ms
# video 1/1 (frame 38/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 3 persons, 33.1ms
# video 1/1 (frame 39/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 3 persons, 45.8ms
# video 1/1 (frame 40/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 4 persons, 39.6ms
# video 1/1 (frame 41/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 5 persons, 45.6ms
# video 1/1 (frame 42/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 5 persons, 41.9ms
# video 1/1 (frame 43/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 4 persons, 38.0ms
# video 1/1 (frame 44/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 3 persons, 56.8ms
# video 1/1 (frame 45/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 3 persons, 45.0ms
# video 1/1 (frame 46/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 4 persons, 40.1ms
# video 1/1 (frame 47/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 4 persons, 40.2ms
# video 1/1 (frame 48/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 4 persons, 41.5ms
# video 1/1 (frame 49/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 6 persons, 38.2ms
# video 1/1 (frame 50/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 3 persons, 40.8ms
# video 1/1 (frame 51/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 4 persons, 33.4ms
# video 1/1 (frame 52/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 5 persons, 33.2ms
# video 1/1 (frame 53/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 5 persons, 34.1ms
# video 1/1 (frame 54/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 5 persons, 33.2ms
# video 1/1 (frame 55/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 4 persons, 39.0ms
# video 1/1 (frame 56/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 5 persons, 40.2ms
# video 1/1 (frame 57/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 5 persons, 32.5ms
# video 1/1 (frame 58/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 4 persons, 34.0ms
# video 1/1 (frame 59/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 5 persons, 30.5ms
# video 1/1 (frame 60/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 5 persons, 32.8ms
# video 1/1 (frame 61/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 5 persons, 32.6ms
# video 1/1 (frame 62/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 5 persons, 37.7ms
# video 1/1 (frame 63/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 5 persons, 35.9ms
# video 1/1 (frame 64/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 4 persons, 31.3ms
# video 1/1 (frame 65/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 3 persons, 36.1ms
# video 1/1 (frame 66/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 3 persons, 35.0ms
# video 1/1 (frame 67/67) /Users/terr/Desktop/dsci_basketball/basketball-optimizer/notebooks/../data/raw/videos/sample_good_shot.mp4: 416x640 5 persons, 40.7ms
# Speed: 1.2ms preprocess, 39.0ms inference, 0.3ms postprocess per image at shape (1, 3, 416, 640)

# %%
Video(
    "../data/processed/shooter_only2.mp4",
)
# Out:
# <video src="../data/processed/shooter_only2.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# The processed video should be in the data/processed directory.
