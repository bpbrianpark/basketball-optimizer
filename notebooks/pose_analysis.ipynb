# %% [markdown]
# # Basketball Shooting Pose Analysis
# This notebook walks through loading pose estimation outputs, engineering joint-angle features, and training a baseline model.

# %%
import sys
from pathlib import Path

# Add project root to Python path so we can import ml module
project_root = Path(__file__).parent.parent if '__file__' in globals() else Path().resolve().parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

import pandas as pd
import numpy as np

from ml.data_pipeline import compute_joint_angles, load_pose_samples
from ml.model_training import train_model

# %%
# TODO: Load pose keypoints exported from the pose estimator
# raw_samples = [...]  # Populate with PoseSample instances
# df = load_pose_samples(raw_samples)
# artifacts = train_model(df, label_column="label", model_dir=Path("models"))
# artifacts.metrics
